# %%
import logging

# %%
# %pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\shorn\documents\github\pyrate\env3\lib\site-packages (1.23.5)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\shorn\documents\github\pyrate\env3\lib\site-packages (3.6.2)Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shorn\documents\github\pyrate\env3\lib\site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in c:\users\shorn\documents\github\pyrate\env3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shorn\documents\github\pyrate\env3\lib\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\shorn\documents\github\pyrate\env3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.19 in c:\users\shorn\documents\github\pyrate\env3\lib\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\shorn\documents\github\pyrate\env3\lib\site-packages (from matplotlib) (22.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\shorn\documents\github\pyrate\env3\lib\site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\shorn\documents\github\pyrate\env3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shorn\documents\github\pyrate\env3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\shorn\documents\github\pyrate\env3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# %pip install scipy
# Out:
# Collecting scipy
#   Using cached scipy-1.9.3-cp311-cp311-win_amd64.whl (39.9 MB)
# Requirement already satisfied: numpy<1.26.0,>=1.18.5 in c:\users\shorn\documents\github\pyrate\env3\lib\site-packages (from scipy) (1.23.5)
# Installing collected packages: scipy
# Successfully installed scipy-1.9.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install pyyaml
# Out:
# Collecting pyyaml
#   Using cached PyYAML-6.0-cp311-cp311-win_amd64.whl (143 kB)
# Installing collected packages: pyyaml
# Successfully installed pyyaml-6.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pyrateoptics import build_rotationally_symmetric_optical_system

# %%
from pyrateoptics import draw

# %%
from pyrateoptics import raytrace

# %%
# (radius, cc, thickness, material, name, options)
components = [(100, 0, 20, 1.5, "lens1front", {"is_stop": True}), (-100, 0, 5, None, "lens1back", {}), (0, 0, 100, None, "image", {})]

# %%
(s, seq) = build_rotationally_symmetric_optical_system(components, name="my_opticalsystem")

# %%
draw(s)

# %%
r = raytrace(s, seq, 11, {"radius": 9.0})

# %%
draw(s, r) # show system + rays
